# %% [markdown]
# <a href="https://colab.research.google.com/github/Nancy727/ComputerVision/blob/main/ORB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread("/content/orbchess.avif")
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
orb=cv2.ORB_create(nfeatures=2000)
kp,des=orb.detectAndCompute(gray_image,None)

# %%
kp_image=cv2.drawKeypoints(gray_image,kp,None,color=(0,255,0),flags=0)
cv2
# Out:
# <module 'cv2' (<google.colab._import_hooks._hook_injector.HookInjectorLoader object at 0x7ec8acb22990>)>

# %%
kp_image_rgb=cv2.cvtColor(kp_image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(kp_image_rgb)
plt.axis("off")
plt.title("ORB Keypoints")
plt.show()
